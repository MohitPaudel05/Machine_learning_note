# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
data ={
    "area":[1500,1800,2400,3000,3500],
    "room":[3,3,4,5,5],
    "price": [300000, 340000, 450000, 500000, 600000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    area  room   price
# 0  1500     3  300000
# 1  1800     3  340000
# 2  2400     4  450000
# 3  3000     5  500000
# 4  3500     5  600000

# %%
#Features(X) and Target_value(y)
X = df[["area", "room"]]
y=df["price"]

# %%
#split the data into train and test sets
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# prediction on the train data
prediction= reg.predict(X_test)
prediction
# Out:
# array([368115.94202899])

# %%
rmse = np.sqrt(mean_squared_error(y_test,prediction))
rmse
# Out:
# np.float64(28115.94202898559)

# %%
residual_error = y_test-prediction
residual_error
# Out:
# 1   -28115.942029
# Name: price, dtype: float64

# %%
sns.scatterplot(x=prediction,y=residual_error)
plt.axhline(y=0, c='red', ls='--')

# %%
sns.scatterplot(x = test_predictions , y = test_residuals)
plt.axhline(y=0, c='red', ls='--')

# %%
sns.displot(x= residual_error, kind='kde');
plt.grid()
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_338660\2045506245.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(x= residual_error, kind='kde');
